# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



def mytrain_test_split(X, y, test_size=0.2, random_state=None):
    if random_state:
        np.random.seed(random_state)


    indices = np.arange(len(X))
    np.random.shuffle(indices)


    test_count = int(len(X) * test_size)


    X_train, X_test = X[indices[test_count:]], X[indices[:test_count]]
    y_train, y_test = y[indices[test_count:]], y[indices[:test_count]]

    return X_train, X_test, y_train, y_test

# %%
df=pd.read_csv('/content/placement.csv')

# %%
df.head() #using my fn  in this dataset
df.shape
# Out:
# (200, 2)

# %%
x_train,x_test,y_train,y_test=mytrain_test_split(df['cgpa'].values,df['package'].values,test_size=0.2,random_state=2)

# %%
pd.DataFrame(x_train,columns=['cgpa'])
# Out:
#      cgpa
# 0    7.14
# 1    8.93
# 2    5.42
# 3    5.10
# 4    7.77
# ..    ...
# 155  7.66
# 156  6.14
# 157  7.78
# 158  7.25
# 159  8.65
#
# [160 rows x 1 columns]

# %%
# initially data had 200 rows and now has only 160 rows
