# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.impute import SimpleImputer
import seaborn as sns
from sklearn.preprocessing import TargetEncoder
from sklearn.preprocessing import MinMaxScaler

pro_wines_df=pd.read_csv('/content/pro_wines_df')

# %%
pro_wines_df
# Out:
#                     winery  ... encoded_type_price
# 0                   Artadi  ...          64.238118
# 1             Vega Sicilia  ...          57.377097
# 2             Vega Sicilia  ...          58.844710
# 3             Vega Sicilia  ...          58.386412
# 4             Vega Sicilia  ...          57.001293
# ...                    ...  ...                ...
# 6379               Contino  ...          41.098537
# 6380  Conreria d'Scala Dei  ...          61.876539
# 6381           Mustiguillo  ...          32.434124
# 6382           Matarromera  ...          57.001293
# 6383              Sei Solo  ...          57.001293
#
# [6384 rows x 15 columns]

# %%
#Transforming the values of all the numeric columns in the range of o to 1 using MinMaxScalar

numeric_cols=pro_wines_df.iloc[:,1:].select_dtypes(include=['int64','float64']).columns
numeric_cols=numeric_cols.drop(['year','price'])
scalar=MinMaxScaler()
scaled_wines_df=pro_wines_df[numeric_cols].copy()
scaled_wines_df=pd.DataFrame(scalar.fit_transform(scaled_wines_df[numeric_cols]),columns=numeric_cols,index=pro_wines_df.index)
scaled_wines_df
# Out:
#         rating  num_reviews      body  ...  encoded_wine_price  encoded_winery_price  encoded_type_price
# 0     1.000000     0.003386  0.666667  ...            0.701340              0.158028            0.436337
# 1     0.857143     0.997743  1.000000  ...            0.847862              0.710153            0.379728
# 2     0.857143     0.663657  1.000000  ...            0.834438              0.703778            0.391837
# 3     0.857143     0.348758  1.000000  ...            0.757553              0.670789            0.388055
# 4     0.857143     0.341422  1.000000  ...            0.878303              0.670789            0.376627
# ...        ...          ...       ...  ...                 ...                   ...                 ...
# 6379  0.000000     0.207111  0.666667  ...            0.022926              0.095071            0.245417
# 6380  0.000000     0.205982  0.666667  ...            0.013212              0.020900            0.416852
# ...

# %%
from google.colab import files

scaled_wines_df.to_csv('scaled_wines_df',index=False)

files.download('scaled_wines_df')
