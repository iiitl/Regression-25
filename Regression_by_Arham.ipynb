# %%
import pandas as pd
import numpy as np

# %%
wines=pd.read_csv("wines_SPA.csv")
wines.head()
# Out:
#           winery           wine  year  rating  num_reviews country  \
# 0  Teso La Monja          Tinto  2013     4.9           58  Espana
# 1         Artadi  Vina El Pison  2018     4.9           31  Espana
# 2   Vega Sicilia          Unico  2009     4.8         1793  Espana
# 3   Vega Sicilia          Unico  1999     4.8         1705  Espana
# 4   Vega Sicilia          Unico  1996     4.8         1309  Espana
#
#              region   price                  type  body  acidity
# 0              Toro  995.00              Toro Red   5.0      3.0
# 1    Vino de Espana  313.50           Tempranillo   4.0      2.0
# 2  Ribera del Duero  324.95  Ribera Del Duero Red   5.0      3.0
# 3  Ribera del Duero  692.96  Ribera Del Duero Red   5.0      3.0
# 4  Ribera del Duero  778.06  Ribera Del Duero Red   5.0      3.0

# %%
wines.shape
# Out:
# (7500, 11)

# %%
wines.isna().sum()
# Out:
# winery            0
# wine              0
# year              2
# rating            0
# num_reviews       0
# country           0
# region            0
# price             0
# type            545
# body           1169
# acidity        1169
# dtype: int64

# %%
#Year column is of no use here
wines.drop('year',axis='columns',inplace=True)

# %%
wines['acidity'].unique() #Uniform
# Out:
# array([ 3.,  2.,  1., nan])

# %%
wines['body'].unique()#Data is uniform
# Out:
# array([ 5.,  4.,  3., nan,  2.])

# %%
#Numerical nan values handling
wines['body'].fillna(wines['body'].median(),inplace=True)
wines['acidity'].fillna(wines['acidity'].median(),inplace=True)
# Out:
# <ipython-input-70-106ae2eb24d2>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wines['body'].fillna(wines['body'].median(),inplace=True)
# <ipython-input-70-106ae2eb24d2>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
wines.isna().sum()
# Out:
# winery           0
# wine             0
# rating           0
# num_reviews      0
# country          0
# region           0
# price            0
# type           545
# body             0
# acidity          0
# dtype: int64

# %%
wines['type'].unique() #Dropinng type as can't add anything to it with choice
# Out:
# array(['Toro Red', 'Tempranillo', 'Ribera Del Duero Red', 'Pedro Ximenez',
#        'Red', 'Sherry', 'Priorat Red', 'Rioja Red', 'Rioja White',
#        'Grenache', nan, 'Cava', 'Verdejo', 'Syrah', 'Monastrell',
#        'Mencia', 'Sparkling', 'Montsant Red', 'Albarino', 'Chardonnay',
#        'Cabernet Sauvignon', 'Sauvignon Blanc'], dtype=object)

# %%
wines.drop('type',axis='columns',inplace=True)

# %%
#Removing outliers from num_reviews
Q1 = wines['num_reviews'].quantile(0.25)
Q3 = wines['num_reviews'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
wines_iqr = wines[(wines['num_reviews'] > lower_bound) & (wines['num_reviews'] < upper_bound)]

# %%
wines_iqr.head()
# Out:
#                  winery                            wine  rating  num_reviews  \
# 12         Vega Sicilia  Unico Reserva Especial Edicion     4.8          438
# 13         Vega Sicilia                           Unico     4.8          417
# 14          Toro Albala       Don PX Convento Seleccion     4.8          398
# 15  Pago de Carraovejas           Cuesta de Las Liebres     4.8          372
# 72         Vega Sicilia  Unico Reserva Especial Edicion     4.7          442
#
#    country            region   price  body  acidity
# 12  Espana  Ribera del Duero  430.00   5.0      3.0
# 13  Espana  Ribera del Duero  925.00   5.0      3.0
# 14  Espana  Montilla-Moriles  350.00   5.0      1.0
# 15  Espana  Ribera del Duero  166.18   5.0      3.0
# 72  Espana  Ribera del Duero  290.00   5.0      3.0

# %%
#Converting datatype to all num
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
wines_iqr['winery']=le.fit_transform(wines_iqr['winery'])
wines_iqr['wine']=le.fit_transform(wines_iqr['wine'])
wines_iqr['country']=le.fit_transform(wines_iqr['country'])
wines_iqr['region']=le.fit_transform(wines_iqr['region'])
# Out:
# <ipython-input-76-d96e57d07530>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wines_iqr['winery']=le.fit_transform(wines_iqr['winery'])
# <ipython-input-76-d96e57d07530>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wines_iqr['wine']=le.fit_transform(wines_iqr['wine'])
# <ipython-input-76-d96e57d07530>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
wines_iqr.head()
# Out:
#     winery  wine  rating  num_reviews  country  region   price  body  acidity
# 12      74    83     4.8          438        0      19  430.00   5.0      3.0
# 13      74    82     4.8          417        0      19  925.00   5.0      3.0
# 14      72    20     4.8          398        0      14  350.00   5.0      1.0
# 15      57    17     4.8          372        0      19  166.18   5.0      3.0
# 72      74    83     4.7          442        0      19  290.00   5.0      3.0

# %%
x=wines_iqr.drop('price',axis='columns')
y=wines_iqr['price']

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits=5, shuffle=True, random_state=20)
for train_index, test_index in kf.split(x, y):
    x_train, x_test = x.iloc[train_index], x.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LinearRegression
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
model_params_reg={
    'svm': svm.SVR(gamma='auto'),
    'random_forest': RandomForestRegressor(),
    'knn': KNeighborsRegressor(),
    'gradient_boosting': GradientBoostingRegressor(),
    'linear_regression': LinearRegression(),
    'decision_tree': DecisionTreeRegressor(),
}

# %%
from sklearn.metrics import r2_score
scores=[]

for model_name, model in model_params_reg.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    score = r2_score(y_test, y_pred)
    scores.append({
        'model': model_name,
        'score': score
    })

# %%
scores
# Out:
# [{'model': 'svm', 'score': 0.7450045338003544},
#  {'model': 'random_forest', 'score': 0.908012440109857},
#  {'model': 'knn', 'score': 0.729447289301342},
#  {'model': 'gradient_boosting', 'score': 0.9277651585649995},
#  {'model': 'linear_regression', 'score': -0.1702811589761375},
#  {'model': 'decision_tree', 'score': 0.8062672409236361}]
