# %% [markdown]
# # Cleaning the data
# **Issue : Applying Various Techniques for Data Cleaning**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

df = pd.read_csv('wines_SPA.csv')
df.head()
# Out:
#           winery           wine  year  rating  num_reviews country  \
# 0  Teso La Monja          Tinto  2013     4.9           58  Espana
# 1         Artadi  Vina El Pison  2018     4.9           31  Espana
# 2   Vega Sicilia          Unico  2009     4.8         1793  Espana
# 3   Vega Sicilia          Unico  1999     4.8         1705  Espana
# 4   Vega Sicilia          Unico  1996     4.8         1309  Espana
#
#              region   price                  type  body  acidity
# 0              Toro  995.00              Toro Red   5.0      3.0
# 1    Vino de Espana  313.50           Tempranillo   4.0      2.0
# 2  Ribera del Duero  324.95  Ribera Del Duero Red   5.0      3.0
# 3  Ribera del Duero  692.96  Ribera Del Duero Red   5.0      3.0
# 4  Ribera del Duero  778.06  Ribera Del Duero Red   5.0      3.0

# %%
df.isnull().sum()
# Out:
# winery            0
# wine              0
# year              2
# rating            0
# num_reviews       0
# country           0
# region            0
# price             0
# type            545
# body           1169
# acidity        1169
# dtype: int64

# %% [markdown]
# **Its clear that only 4 columns which have NaN values which are year, type, body and acidity**

# %%
df.describe()
# Out:
#             rating   num_reviews        price         body      acidity
# count  7500.000000   7500.000000  7500.000000  6331.000000  6331.000000
# mean      4.254933    451.109067    60.095822     4.158427     2.946612
# std       0.118029    723.001856   150.356676     0.583352     0.248202
# min       4.200000     25.000000     4.990000     2.000000     1.000000
# 25%       4.200000    389.000000    18.900000     4.000000     3.000000
# 50%       4.200000    404.000000    28.530000     4.000000     3.000000
# 75%       4.200000    415.000000    51.350000     5.000000     3.000000
# max       4.900000  32624.000000  3119.080000     5.000000     3.000000

# %% [markdown]
# **Printing the null values of year column**

# %%
df[df['year'].isnull()]
# Out:
#            winery                            wine year  rating  num_reviews  \
# 46   Vega Sicilia  Unico Reserva Especial Edicion  NaN     4.7        12421
# 851      La Unica                  Fourth Edition  NaN     4.4          131
#
#     country            region  price                  type  body  acidity
# 46   Espana  Ribera del Duero  423.5  Ribera Del Duero Red   5.0      3.0
# 851  Espana    Vino de Espana   40.0           Tempranillo   4.0      2.0

# %% [markdown]
# **The year column had values in string format so first we have to change it to int**

# %%
df['year'] = pd.to_numeric(df['year'], errors='coerce')

# %% [markdown]
# **As we are dealing with year so i thought using interpolate will be good option here**

# %%
df['year'] = df['year'].interpolate(method = 'linear')

# %%
df['year'].isnull().sum()
# Out:
# np.int64(0)

# %%
df[df['type'].isnull()]
# Out:
#                       winery                                wine    year  \
# 120            Finca Moncloa                    Tintilla de Rota  2016.0
# 147          Rafael Palacios           Sorte O Soro Val do Bibei  2019.0
# 156     Gutierrez de la Vega  Recondita Armonia Monastrell Dulce  1987.0
# 254      Costers del Siurana                      Dolc de L'Obac  2006.0
# 288   Francisco Garcia Perez          Adega do Moucho Treixadura  2017.0
# ...                      ...                                 ...     ...
# 7440                Binigrau                              Nounat  2020.0
# 7462          Ramon do Casar                          Treixadura  2020.0
# 7465                Binigrau                              Nounat  2020.0
# 7487          Ramon do Casar                          Treixadura  2020.0
# 7490                Binigrau                              Nounat  2020.0
#
#       rating  num_reviews country      region      price type  body  acidity
# 120      4.7           92  Espana       Cadiz   43.13000  NaN   NaN      NaN
# 147      4.7           37  Espana  Valdeorras  194.86000  NaN   NaN      NaN
# 156      4.7           27  Espana    Alicante   81.90000  NaN   NaN      NaN
# 254      4.6           94  Espana    Priorato  117.23942  NaN   NaN      NaN
# 288      4.6           53  Espana     Ribeiro   34.50000  NaN   NaN      NaN
# ...      ...          ...     ...         ...        ...  ...   ...      ...
# 7440     4.2          404  Espana    Mallorca   19.90000  NaN   NaN      NaN
# 7462     4.2          407  Espana     Ribeiro   11.95000  NaN   NaN      NaN
# 7465     4.2          404  Espana    Mallorca   19.90000  NaN   NaN      NaN
# 7487     4.2          407  Espana     Ribeiro   11.95000  NaN   NaN      NaN
# 7490     4.2          404  Espana    Mallorca   19.90000  NaN   NaN      NaN
#
# [545 rows x 11 columns]

# %% [markdown]
# **From the below line of code its clear that are only 21 unique values for the 'type' column**

# %%
df['type'].unique()
# Out:
# array(['Toro Red', 'Tempranillo', 'Ribera Del Duero Red', 'Pedro Ximenez',
#        'Red', 'Sherry', 'Priorat Red', 'Rioja Red', 'Rioja White',
#        'Grenache', nan, 'Cava', 'Verdejo', 'Syrah', 'Monastrell',
#        'Mencia', 'Sparkling', 'Montsant Red', 'Albarino', 'Chardonnay',
#        'Cabernet Sauvignon', 'Sauvignon Blanc'], dtype=object)

# %% [markdown]
# **From the below code we found out that the mode of the type columns is 'Rioja Red' which can be used to fillna**

# %%
def unique_print():
  for i in df['type'].unique():
    print((df['type']==i).sum(), i)
unique_print()
# Out:
# 296 Toro Red
# 291 Tempranillo
# 1407 Ribera Del Duero Red
# 35 Pedro Ximenez
# 864 Red
# 274 Sherry
# 674 Priorat Red
# 2357 Rioja Red
# 92 Rioja White
# 35 Grenache
# 0 nan
# 33 Cava
# 27 Verdejo
# 15 Syrah
# 18 Monastrell
# 235 Mencia
# 5 Sparkling
# 17 Montsant Red
# 252 Albarino
# 13 Chardonnay
# 11 Cabernet Sauvignon
# 4 Sauvignon Blanc

# %% [markdown]
# **We used mode to fill the NaN values in the 'type' column**
# *(Honestly, I wasn't able to find a better way)*

# %%
df['type'] = df['type'].fillna(df['type'].mode()[0])
df['type'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **I created a function to fill all the numeric column with NaN values with the mean of that column**

# %%
def filling_na(df):
  for i in df.select_dtypes(include = 'number' ).columns:
    df[i] = df[i].fillna(df[i].mean())
  return df

# %%
filling_na(df)
# Out:
#                     winery             wine    year  rating  num_reviews  \
# 0            Teso La Monja            Tinto  2013.0     4.9           58
# 1                   Artadi    Vina El Pison  2018.0     4.9           31
# 2             Vega Sicilia            Unico  2009.0     4.8         1793
# 3             Vega Sicilia            Unico  1999.0     4.8         1705
# 4             Vega Sicilia            Unico  1996.0     4.8         1309
# ...                    ...              ...     ...     ...          ...
# 7495               Contino          Reserva  2016.0     4.2          392
# 7496  Conreria d'Scala Dei    Les Brugueres  2018.0     4.2          390
# 7497           Mustiguillo  Finca Terrerazo  2017.0     4.2          390
# 7498           Matarromera     Gran Reserva  2011.0     4.2          389
# 7499              Sei Solo         Preludio  2016.0     4.2          388
#
#      country            region   price                  type  body  acidity
# 0     Espana              Toro  995.00              Toro Red   5.0      3.0
# 1     Espana    Vino de Espana  313.50           Tempranillo   4.0      2.0
# 2     Espana  Ribera del Duero  324.95  Ribera Del Duero Red   5.0      3.0
# 3     Espana  Ribera del Duero  692.96  Ribera Del Duero Red   5.0      3.0
# 4     Espana  Ribera del Duero  778.06  Ribera Del Duero Red   5.0      3.0
# ...      ...               ...     ...                   ...   ...      ...
# 7495  Espana             Rioja   19.98             Rioja Red   4.0      3.0
# 7496  Espana          Priorato   16.76           Priorat Red   4.0      3.0
# 7497  Espana      El Terrerazo   24.45                   Red   4.0      3.0
# 7498  Espana  Ribera del Duero   64.50  Ribera Del Duero Red   5.0      3.0
# 7499  Espana  Ribera del Duero   31.63  Ribera Del Duero Red   5.0      3.0
#
# [7500 rows x 11 columns]

# %% [markdown]
# **Now all the NaN values are handeled**

# %%
df.isnull().sum()
# Out:
# winery         0
# wine           0
# year           0
# rating         0
# num_reviews    0
# country        0
# region         0
# price          0
# type           0
# body           0
# acidity        0
# dtype: int64

# %% [markdown]
# **Now droping all the duplicates**

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#           winery           wine    year  rating  num_reviews country  \
# 0  Teso La Monja          Tinto  2013.0     4.9           58  Espana
# 1         Artadi  Vina El Pison  2018.0     4.9           31  Espana
# 2   Vega Sicilia          Unico  2009.0     4.8         1793  Espana
# 3   Vega Sicilia          Unico  1999.0     4.8         1705  Espana
# 4   Vega Sicilia          Unico  1996.0     4.8         1309  Espana
#
#              region   price                  type  body  acidity
# 0              Toro  995.00              Toro Red   5.0      3.0
# 1    Vino de Espana  313.50           Tempranillo   4.0      2.0
# 2  Ribera del Duero  324.95  Ribera Del Duero Red   5.0      3.0
# 3  Ribera del Duero  692.96  Ribera Del Duero Red   5.0      3.0
# 4  Ribera del Duero  778.06  Ribera Del Duero Red   5.0      3.0

# %%
df = df.drop(['country'], axis="columns")
df.head()
# Out:
#           winery           wine    year  rating  num_reviews  \
# 0  Teso La Monja          Tinto  2013.0     4.9           58
# 1         Artadi  Vina El Pison  2018.0     4.9           31
# 2   Vega Sicilia          Unico  2009.0     4.8         1793
# 3   Vega Sicilia          Unico  1999.0     4.8         1705
# 4   Vega Sicilia          Unico  1996.0     4.8         1309
#
#              region   price                  type  body  acidity
# 0              Toro  995.00              Toro Red   5.0      3.0
# 1    Vino de Espana  313.50           Tempranillo   4.0      2.0
# 2  Ribera del Duero  324.95  Ribera Del Duero Red   5.0      3.0
# 3  Ribera del Duero  692.96  Ribera Del Duero Red   5.0      3.0
# 4  Ribera del Duero  778.06  Ribera Del Duero Red   5.0      3.0

# %%
df.to_csv('wines_SPA_cleaned.csv', index=False)

# %% [markdown]
# # <font color="green"> DONE !</font>
