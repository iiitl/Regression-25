# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv('wines_SPA.csv')

# %%
df.shape
# Out:
# (7500, 11)

# %%
df.head()
# Out:
#           winery           wine  year  rating  num_reviews country  \
# 0  Teso La Monja          Tinto  2013     4.9           58  Espana
# 1         Artadi  Vina El Pison  2018     4.9           31  Espana
# 2   Vega Sicilia          Unico  2009     4.8         1793  Espana
# 3   Vega Sicilia          Unico  1999     4.8         1705  Espana
# 4   Vega Sicilia          Unico  1996     4.8         1309  Espana
#
#              region   price                  type  body  acidity
# 0              Toro  995.00              Toro Red   5.0      3.0
# 1    Vino de Espana  313.50           Tempranillo   4.0      2.0
# 2  Ribera del Duero  324.95  Ribera Del Duero Red   5.0      3.0
# 3  Ribera del Duero  692.96  Ribera Del Duero Red   5.0      3.0
# 4  Ribera del Duero  778.06  Ribera Del Duero Red   5.0      3.0

# %%
df.sample(15)
# Out:
#                     winery                                       wine  year  \
# 6239    Portal del Priorat                      Clos del Portal Somni  2014
# 2382         La Rioja Alta                       Vina Alberdi Crianza  2018
# 5722           Matarromera                               Gran Reserva  2011
# 1489        Perez Barquero  Gran Barquero Palo Cortado Solera 25 Anos  N.V.
# 3863    Portal del Priorat                      Clos del Portal Somni  2014
# 6045  Conreria d'Scala Dei                              Les Brugueres  2018
# 4536        Ramon do Casar                                 Treixadura  2020
# 6393                Artadi                                 Valdegines  2016
# 5661        Ramon do Casar                                 Treixadura  2020
# 3469               Contino                                    Reserva  2016
# 6419               Contino                             Rioja Graciano  2011
# 4998              Sei Solo                                   Preludio  2016
# 3703      Sierra Cantabria                          Coleccion Privada  2012
# 3067                Artadi                                 Valdegines  2016
# 4220  Conreria d'Scala Dei                              Les Brugueres  2018
#
#       rating  num_reviews country            region  price  \
# 6239     4.2          404  Espana          Priorato  77.36
# 2382     4.2          410  Espana             Rioja  13.58
# 5722     4.2          389  Espana  Ribera del Duero  64.50
# 1489     4.3          108  Espana  Montilla-Moriles  34.90
# 3863     4.2          404  Espana          Priorato  77.36
# 6045     4.2          390  Espana          Priorato  16.76
# 4536     4.2          407  Espana           Ribeiro  11.95
# 6393     4.2          398  Espana    Vino de Espana  48.96
# 5661     4.2          407  Espana           Ribeiro  11.95
# 3469     4.2          392  Espana             Rioja  19.98
# 6419     4.2          395  Espana             Rioja  61.94
# 4998     4.2          388  Espana  Ribera del Duero  31.63
# 3703     4.2          420  Espana             Rioja  28.30
# 3067     4.2          398  Espana    Vino de Espana  48.96
# 4220     4.2          390  Espana          Priorato  16.76
#
#                       type  body  acidity
# 6239           Priorat Red   4.0      3.0
# 2382             Rioja Red   4.0      3.0
# 5722  Ribera Del Duero Red   5.0      3.0
# 1489                   NaN   NaN      NaN
# 3863           Priorat Red   4.0      3.0
# 6045           Priorat Red   4.0      3.0
# 4536                   NaN   NaN      NaN
# 6393           Tempranillo   4.0      2.0
# 5661                   NaN   NaN      NaN
# 3469             Rioja Red   4.0      3.0
# 6419             Rioja Red   4.0      3.0
# 4998  Ribera Del Duero Red   5.0      3.0
# 3703             Rioja Red   4.0      3.0
# 3067           Tempranillo   4.0      2.0
# 4220           Priorat Red   4.0      3.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   winery       7500 non-null   object
#  1   wine         7500 non-null   object
#  2   year         7498 non-null   object
#  3   rating       7500 non-null   float64
#  4   num_reviews  7500 non-null   int64
#  5   country      7500 non-null   object
#  6   region       7500 non-null   object
#  7   price        7500 non-null   float64
#  8   type         6955 non-null   object
#  9   body         6331 non-null   float64
#  10  acidity      6331 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 644.7+ KB

# %%
df['year']=df['year'].replace('N.V.', pd.NA)
df['year']=df['year'].fillna(df['year'].mode()[0])
df['year']=df['year'].astype(int)

# %%
df.isnull().sum()
# Out:
# winery            0
# wine              0
# year              2
# rating            0
# num_reviews       0
# country           0
# region            0
# price             0
# type            545
# body           1169
# acidity        1169
# dtype: int64

# %%
df.describe()
# Out:
#               year       rating   num_reviews        price         body  \
# count  7500.000000  7500.000000   7500.000000  7500.000000  6331.000000
# mean   2013.399333     4.254933    451.109067    60.095822     4.158427
# std       6.821921     0.118029    723.001856   150.356676     0.583352
# min    1910.000000     4.200000     25.000000     4.990000     2.000000
# 25%    2011.000000     4.200000    389.000000    18.900000     4.000000
# 50%    2015.000000     4.200000    404.000000    28.530000     4.000000
# 75%    2017.000000     4.200000    415.000000    51.350000     5.000000
# max    2021.000000     4.900000  32624.000000  3119.080000     5.000000
#
#            acidity
# count  6331.000000
# mean      2.946612
# std       0.248202
# min       1.000000
# 25%       3.000000
# 50%       3.000000
# 75%       3.000000
# max       3.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(5452)

# %%
df=df.drop_duplicates()

# %%
df.loc[:,'acidity']=df.groupby('wine')['acidity'].transform(lambda x:x.fillna(x.median()))

# %%
df.loc[:,'body']=df.groupby('wine')['body'].transform(lambda x:x.fillna(x.median()))

# %%
df.loc[:,'acidity']=df['acidity'].fillna(df['acidity'].mean())

# %%
df.loc[:,'body']=df['body'].fillna(df['body'].mean())

# %%
df=df.dropna(subset=['year'])

# %%
df.loc[:,'type'] = df.groupby('wine')['type'].transform(lambda x:x.fillna(x.mode()))

# %%
df=df.dropna(subset=['type'])

# %%
df.isnull().sum()
# Out:
# winery         0
# wine           0
# year           0
# rating         0
# num_reviews    0
# country        0
# region         0
# price          0
# type           0
# body           0
# acidity        0
# dtype: int64

# %%
df = df.drop(columns=['country'])

# %%
df['type'].nunique()
# Out:
# 21

# %%
le = LabelEncoder()
df['type'] = le.fit_transform(df['type'])

# %%
df.sample(5)
# Out:
#              winery                          wine  year  rating  num_reviews  \
# 1712  Jimenez-Landi             Cantos del Diablo  2018     4.3           38
# 1368  Casa Castillo                    Pie Franco  2016     4.3          200
# 1482   Clos Mogador                       Priorat  2000     4.3          111
# 1071          Xaloc                        Monada  2013     4.4           33
# 1008        Llopart  Cava Original Brut (Espumos)  2010     4.4           49
#
#         region   price  type  body  acidity
# 1712  Mentrida  197.00     4   5.0      3.0
# 1368   Jumilla   59.90     6   5.0      3.0
# 1482  Priorato  100.00     9   4.0      3.0
# 1071  Mallorca   35.40    10   4.0      3.0
# 1008      Cava   52.95     2   2.0      3.0
